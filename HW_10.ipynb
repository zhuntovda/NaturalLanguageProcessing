# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2021-11-24 10:27:53--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 172.67.186.54, 104.21.92.44, 2606:4700:3030::6815:5c2c, ...
# Connecting to www.manythings.org (www.manythings.org)|172.67.186.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14385451 (14M) [application/zip]
# Saving to: ‘rus-eng.zip.1’
#
# rus-eng.zip.1       100%[===================>]  13.72M  9.40MB/s    in 1.5s
#
# 2021-11-24 10:27:55 (9.40 MB/s) - ‘rus-eng.zip.1’ saved [14385451/14385451]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# mkdir: cannot create directory ‘rus-eng’: File exists
# Archive:  rus-eng.zip
# replace rus-eng/rus.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 69M
# drwxr-xr-x 2 root root 4.0K Nov 24 10:31 .
# drwxr-xr-x 1 root root 4.0K Nov 24 10:27 ..
# -rw-r--r-- 1 root root 1.5K Jul 14 10:16 _about.txt
# -rw-r--r-- 1 root root  69M Jul 14 10:16 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (431097, 431097)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 34 ----> она
# 298 ----> всего
# 467 ----> лишь
# 250 ----> реб
# 300 ----> нок
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 312 ----> she's
# 72 ----> just
# 9 ----> a
# 629 ----> child
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru1 = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=False,
                                   recurrent_initializer='glorot_uniform')
    self.gru2 = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    x = self.gru1(x, initial_state = hidden)
    output, state = self.gru2(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru1 = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=False,
                                   recurrent_initializer='glorot_uniform')
    self.gru2 = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    x = self.gru1(x, initial_state = hidden)
    output, state = self.gru2(x, initial_state = hidden)

    # passing the concatenated vector to the GRU
    #output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7260])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.7606
# Epoch 1 Batch 100 Loss 2.2396
# Epoch 1 Batch 200 Loss 2.1138
# Epoch 1 Batch 300 Loss 1.8296
# Epoch 1 Batch 400 Loss 1.6912
# Epoch 1 Batch 500 Loss 1.6031
# Epoch 1 Batch 600 Loss 1.4765
# Epoch 1 Batch 700 Loss 1.4137
# Epoch 1 Batch 800 Loss 1.3156
# Epoch 1 Batch 900 Loss 1.2389
# Epoch 1 Batch 1000 Loss 1.2998
# Epoch 1 Batch 1100 Loss 1.2584
# Epoch 1 Batch 1200 Loss 1.1785
# Epoch 1 Loss 1.5818
# Time taken for 1 epoch 275.5769238471985 sec
#
# Epoch 2 Batch 0 Loss 1.1423
# Epoch 2 Batch 100 Loss 0.9967
# Epoch 2 Batch 200 Loss 1.0027
# Epoch 2 Batch 300 Loss 0.9524
# Epoch 2 Batch 400 Loss 0.8824
# Epoch 2 Batch 500 Loss 0.9901
# Epoch 2 Batch 600 Loss 0.9751
# Epoch 2 Batch 700 Loss 0.9055
# Epoch 2 Batch 800 Loss 0.7410
# Epoch 2 Batch 900 Loss 0.8909
# Epoch 2 Batch 1000 Loss 0.7627
# Epoch 2 Batch 1100 Loss 0.8780
# Epoch 2 Batch 1200 Loss 0.8535
# Epoch 2 Loss 0.9368
# Time taken for 1 epoch 248.7433478832245 sec
#
# Epoch 3 Batch 0 Loss 0.6752
# Epoch 3 Batch 100 Loss 0.6327
# Epoch 3 Batch 200 Loss 0.6579
# Epoch 3 Batch 300 Loss 0.7074
# Epoch 3 Batch 400 Loss 0.6890
# Epoch 3 Batch 500 Loss 0.6801
# Epoch 3 Batch 600 Loss 0.6867
# Epoch 3 Batch 700 Loss 0.6458
# Epoch 3 Batch 800 Loss 0.5924
# Epoch 3 Batch 900 Loss 0.7381
# Epoch 3 Batch 1000 Loss 0.7535
# Epoch 3 Batch 1100 Loss 0.7243
# Epoch 3 Batch 1200 Loss 0.6423
# Epoch 3 Loss 0.6595
# Time taken for 1 epoch 246.6364974975586 sec
#
# Epoch 4 Batch 0 Loss 0.5175
# Epoch 4 Batch 100 Loss 0.3950
# Epoch 4 Batch 200 Loss 0.5060
# Epoch 4 Batch 300 Loss 0.4961
# Epoch 4 Batch 400 Loss 0.4663
# Epoch 4 Batch 500 Loss 0.5101
# Epoch 4 Batch 600 Loss 0.4724
# Epoch 4 Batch 700 Loss 0.4669
# Epoch 4 Batch 800 Loss 0.4582
# Epoch 4 Batch 900 Loss 0.4994
# Epoch 4 Batch 1000 Loss 0.4335
# Epoch 4 Batch 1100 Loss 0.4309
# Epoch 4 Batch 1200 Loss 0.5075
# Epoch 4 Loss 0.4889
# Time taken for 1 epoch 247.9241659641266 sec
#
# Epoch 5 Batch 0 Loss 0.3836
# Epoch 5 Batch 100 Loss 0.3180
# Epoch 5 Batch 200 Loss 0.2850
# Epoch 5 Batch 300 Loss 0.3964
# Epoch 5 Batch 400 Loss 0.3469
# Epoch 5 Batch 500 Loss 0.3745
# Epoch 5 Batch 600 Loss 0.4135
# Epoch 5 Batch 700 Loss 0.4077
# Epoch 5 Batch 800 Loss 0.3610
# Epoch 5 Batch 900 Loss 0.3799
# Epoch 5 Batch 1000 Loss 0.3456
# Epoch 5 Batch 1100 Loss 0.4144
# Epoch 5 Batch 1200 Loss 0.3608
# Epoch 5 Loss 0.3793
# Time taken for 1 epoch 246.63498282432556 sec
#
# Epoch 6 Batch 0 Loss 0.2806
# Epoch 6 Batch 100 Loss 0.2386
# Epoch 6 Batch 200 Loss 0.2103
# Epoch 6 Batch 300 Loss 0.2231
# Epoch 6 Batch 400 Loss 0.2403
# Epoch 6 Batch 500 Loss 0.3308
# Epoch 6 Batch 600 Loss 0.3651
# Epoch 6 Batch 700 Loss 0.3511
# Epoch 6 Batch 800 Loss 0.3502
# Epoch 6 Batch 900 Loss 0.2657
# Epoch 6 Batch 1000 Loss 0.3429
# Epoch 6 Batch 1100 Loss 0.3178
# Epoch 6 Batch 1200 Loss 0.3070
# Epoch 6 Loss 0.3079
# Time taken for 1 epoch 247.32920932769775 sec
#
# Epoch 7 Batch 0 Loss 0.2157
# Epoch 7 Batch 100 Loss 0.2600
# Epoch 7 Batch 200 Loss 0.2396
# Epoch 7 Batch 300 Loss 0.1824
# Epoch 7 Batch 400 Loss 0.2821
# Epoch 7 Batch 500 Loss 0.2299
# Epoch 7 Batch 600 Loss 0.2933
# Epoch 7 Batch 700 Loss 0.2112
# Epoch 7 Batch 800 Loss 0.2718
# Epoch 7 Batch 900 Loss 0.3334
# Epoch 7 Batch 1000 Loss 0.2648
# Epoch 7 Batch 1100 Loss 0.2671
# Epoch 7 Batch 1200 Loss 0.2526
# Epoch 7 Loss 0.2596
# Time taken for 1 epoch 246.00406289100647 sec
#
# Epoch 8 Batch 0 Loss 0.2486
# Epoch 8 Batch 100 Loss 0.2233
# Epoch 8 Batch 200 Loss 0.1794
# Epoch 8 Batch 300 Loss 0.2150
# Epoch 8 Batch 400 Loss 0.2041
# Epoch 8 Batch 500 Loss 0.2165
# Epoch 8 Batch 600 Loss 0.2160
# Epoch 8 Batch 700 Loss 0.1937
# Epoch 8 Batch 800 Loss 0.2386
# Epoch 8 Batch 900 Loss 0.2207
# Epoch 8 Batch 1000 Loss 0.2501
# Epoch 8 Batch 1100 Loss 0.2402
# Epoch 8 Batch 1200 Loss 0.2712
# Epoch 8 Loss 0.2308
# Time taken for 1 epoch 247.41519713401794 sec
#
# Epoch 9 Batch 0 Loss 0.1641
# Epoch 9 Batch 100 Loss 0.1927
# Epoch 9 Batch 200 Loss 0.2030
# Epoch 9 Batch 300 Loss 0.2047
# Epoch 9 Batch 400 Loss 0.1879
# Epoch 9 Batch 500 Loss 0.1875
# Epoch 9 Batch 600 Loss 0.2140
# Epoch 9 Batch 700 Loss 0.2369
# Epoch 9 Batch 800 Loss 0.2601
# Epoch 9 Batch 900 Loss 0.2003
# Epoch 9 Batch 1000 Loss 0.2337
# Epoch 9 Batch 1100 Loss 0.2741
# Epoch 9 Batch 1200 Loss 0.2326
# Epoch 9 Loss 0.2104
# Time taken for 1 epoch 246.2579312324524 sec
#
# Epoch 10 Batch 0 Loss 0.1661
# Epoch 10 Batch 100 Loss 0.1668
# Epoch 10 Batch 200 Loss 0.1998
# Epoch 10 Batch 300 Loss 0.1771
# Epoch 10 Batch 400 Loss 0.1399
# Epoch 10 Batch 500 Loss 0.1740
# Epoch 10 Batch 600 Loss 0.1722
# Epoch 10 Batch 700 Loss 0.1863
# Epoch 10 Batch 800 Loss 0.2261
# Epoch 10 Batch 900 Loss 0.1803
# Epoch 10 Batch 1000 Loss 0.1695
# Epoch 10 Batch 1100 Loss 0.2511
# Epoch 10 Batch 1200 Loss 0.2525
# Epoch 10 Loss 0.1966
# Time taken for 1 epoch 247.26934027671814 sec
#
# Epoch 11 Batch 0 Loss 0.1612
# Epoch 11 Batch 100 Loss 0.1894
# Epoch 11 Batch 200 Loss 0.1907
# Epoch 11 Batch 300 Loss 0.1278
# Epoch 11 Batch 400 Loss 0.1430
# Epoch 11 Batch 500 Loss 0.1651
# Epoch 11 Batch 600 Loss 0.1861
# Epoch 11 Batch 700 Loss 0.2064
# Epoch 11 Batch 800 Loss 0.1878
# Epoch 11 Batch 900 Loss 0.2135
# Epoch 11 Batch 1000 Loss 0.2006
# Epoch 11 Batch 1100 Loss 0.1938
# Epoch 11 Batch 1200 Loss 0.2155
# Epoch 11 Loss 0.1878
# Time taken for 1 epoch 245.46201157569885 sec
#
# Epoch 12 Batch 0 Loss 0.1720
# Epoch 12 Batch 100 Loss 0.1567
# Epoch 12 Batch 200 Loss 0.1546
# Epoch 12 Batch 300 Loss 0.2034
# Epoch 12 Batch 400 Loss 0.1699
# Epoch 12 Batch 500 Loss 0.1536
# Epoch 12 Batch 600 Loss 0.2074
# Epoch 12 Batch 700 Loss 0.1997
# Epoch 12 Batch 800 Loss 0.1990
# Epoch 12 Batch 900 Loss 0.1708
# Epoch 12 Batch 1000 Loss 0.2280
# Epoch 12 Batch 1100 Loss 0.1745
# Epoch 12 Batch 1200 Loss 0.2157
# Epoch 12 Loss 0.1823
# Time taken for 1 epoch 247.1670753955841 sec
#
# Epoch 13 Batch 0 Loss 0.1717
# Epoch 13 Batch 100 Loss 0.1881
# Epoch 13 Batch 200 Loss 0.1399
# Epoch 13 Batch 300 Loss 0.1724
# Epoch 13 Batch 400 Loss 0.1522
# Epoch 13 Batch 500 Loss 0.1567
# Epoch 13 Batch 600 Loss 0.2066
# Epoch 13 Batch 700 Loss 0.1988
# Epoch 13 Batch 800 Loss 0.1829
# Epoch 13 Batch 900 Loss 0.1969
# Epoch 13 Batch 1000 Loss 0.1985
# Epoch 13 Batch 1100 Loss 0.1638
# Epoch 13 Batch 1200 Loss 0.1989
# Epoch 13 Loss 0.1763
# Time taken for 1 epoch 246.27295303344727 sec
#
# Epoch 14 Batch 0 Loss 0.1425
# Epoch 14 Batch 100 Loss 0.1093
# Epoch 14 Batch 200 Loss 0.1222
# Epoch 14 Batch 300 Loss 0.1569
# Epoch 14 Batch 400 Loss 0.1494
# Epoch 14 Batch 500 Loss 0.1900
# Epoch 14 Batch 600 Loss 0.1592
# Epoch 14 Batch 700 Loss 0.1732
# Epoch 14 Batch 800 Loss 0.1852
# Epoch 14 Batch 900 Loss 0.1542
# Epoch 14 Batch 1000 Loss 0.2471
# Epoch 14 Batch 1100 Loss 0.1415
# Epoch 14 Batch 1200 Loss 0.1659
# Epoch 14 Loss 0.1723
# Time taken for 1 epoch 247.49492478370667 sec
#
# Epoch 15 Batch 0 Loss 0.1918
# Epoch 15 Batch 100 Loss 0.1126
# Epoch 15 Batch 200 Loss 0.1632
# Epoch 15 Batch 300 Loss 0.1850
# Epoch 15 Batch 400 Loss 0.1232
# Epoch 15 Batch 500 Loss 0.1492
# Epoch 15 Batch 600 Loss 0.1711
# Epoch 15 Batch 700 Loss 0.1676
# Epoch 15 Batch 800 Loss 0.1342
# Epoch 15 Batch 900 Loss 0.2326
# Epoch 15 Batch 1000 Loss 0.1568
# Epoch 15 Batch 1100 Loss 0.1598
# Epoch 15 Batch 1200 Loss 0.1669
# Epoch 15 Loss 0.1705
# Time taken for 1 epoch 246.55395555496216 sec
#
# Epoch 16 Batch 0 Loss 0.1791
# Epoch 16 Batch 100 Loss 0.1271
# Epoch 16 Batch 200 Loss 0.1592
# Epoch 16 Batch 300 Loss 0.1792
# Epoch 16 Batch 400 Loss 0.1709
# Epoch 16 Batch 500 Loss 0.1736
# Epoch 16 Batch 600 Loss 0.1338
# Epoch 16 Batch 700 Loss 0.2271
# Epoch 16 Batch 800 Loss 0.1290
# Epoch 16 Batch 900 Loss 0.2003
# Epoch 16 Batch 1000 Loss 0.1943
# Epoch 16 Batch 1100 Loss 0.2285
# Epoch 16 Batch 1200 Loss 0.1724
# Epoch 16 Loss 0.1696
# Time taken for 1 epoch 247.3272807598114 sec
#
# Epoch 17 Batch 0 Loss 0.1279
# Epoch 17 Batch 100 Loss 0.1571
# Epoch 17 Batch 200 Loss 0.1654
# Epoch 17 Batch 300 Loss 0.1038
# Epoch 17 Batch 400 Loss 0.1334
# Epoch 17 Batch 500 Loss 0.2029
# Epoch 17 Batch 600 Loss 0.1490
# Epoch 17 Batch 700 Loss 0.1912
# Epoch 17 Batch 800 Loss 0.1522
# Epoch 17 Batch 900 Loss 0.1619
# Epoch 17 Batch 1000 Loss 0.1983
# Epoch 17 Batch 1100 Loss 0.2875
# Epoch 17 Batch 1200 Loss 0.2206
# Epoch 17 Loss 0.1684
# Time taken for 1 epoch 246.2811393737793 sec
#
# Epoch 18 Batch 0 Loss 0.1638
# Epoch 18 Batch 100 Loss 0.1852
# Epoch 18 Batch 200 Loss 0.1534
# Epoch 18 Batch 300 Loss 0.1237
# Epoch 18 Batch 400 Loss 0.1670
# Epoch 18 Batch 500 Loss 0.1449
# Epoch 18 Batch 600 Loss 0.2024
# Epoch 18 Batch 700 Loss 0.2142
# Epoch 18 Batch 800 Loss 0.2214
# Epoch 18 Batch 900 Loss 0.1867
# Epoch 18 Batch 1000 Loss 0.1805
# Epoch 18 Batch 1100 Loss 0.1981
# Epoch 18 Batch 1200 Loss 0.2187
# Epoch 18 Loss 0.1665
# Time taken for 1 epoch 247.48544263839722 sec
#
# Epoch 19 Batch 0 Loss 0.1205
# Epoch 19 Batch 100 Loss 0.1127
# Epoch 19 Batch 200 Loss 0.1588
# Epoch 19 Batch 300 Loss 0.1213
# Epoch 19 Batch 400 Loss 0.0958
# Epoch 19 Batch 500 Loss 0.1535
# Epoch 19 Batch 600 Loss 0.1675
# Epoch 19 Batch 700 Loss 0.1885
# Epoch 19 Batch 800 Loss 0.1554
# Epoch 19 Batch 900 Loss 0.1598
# Epoch 19 Batch 1000 Loss 0.2458
# Epoch 19 Batch 1100 Loss 0.1810
# Epoch 19 Batch 1200 Loss 0.1429
# Epoch 19 Loss 0.1693
# Time taken for 1 epoch 245.98979377746582 sec
#
# Epoch 20 Batch 0 Loss 0.1583
# Epoch 20 Batch 100 Loss 0.1481
# Epoch 20 Batch 200 Loss 0.1798
# Epoch 20 Batch 300 Loss 0.1144
# Epoch 20 Batch 400 Loss 0.1258
# Epoch 20 Batch 500 Loss 0.1659
# Epoch 20 Batch 600 Loss 0.1436
# Epoch 20 Batch 700 Loss 0.1705
# Epoch 20 Batch 800 Loss 0.1712
# Epoch 20 Batch 900 Loss 0.1686
# Epoch 20 Batch 1000 Loss 0.1835
# Epoch 20 Batch 1100 Loss 0.1986
# Epoch 20 Batch 1200 Loss 0.1720
# Epoch 20 Loss 0.1680
# Time taken for 1 epoch 246.48935914039612 sec
#
# Epoch 21 Batch 0 Loss 0.1144
# Epoch 21 Batch 100 Loss 0.1371
# Epoch 21 Batch 200 Loss 0.1257
# Epoch 21 Batch 300 Loss 0.1873
# Epoch 21 Batch 400 Loss 0.1473
# Epoch 21 Batch 500 Loss 0.1771
# Epoch 21 Batch 600 Loss 0.1773
# Epoch 21 Batch 700 Loss 0.1850
# Epoch 21 Batch 800 Loss 0.2057
# Epoch 21 Batch 900 Loss 0.1930
# Epoch 21 Batch 1000 Loss 0.1847
# Epoch 21 Batch 1100 Loss 0.2105
# Epoch 21 Batch 1200 Loss 0.2228
# Epoch 21 Loss 0.1664
# Time taken for 1 epoch 245.59337544441223 sec
#
# Epoch 22 Batch 0 Loss 0.1322
# Epoch 22 Batch 100 Loss 0.1634
# Epoch 22 Batch 200 Loss 0.1496
# Epoch 22 Batch 300 Loss 0.1454
# Epoch 22 Batch 400 Loss 0.1465
# Epoch 22 Batch 500 Loss 0.1525
# Epoch 22 Batch 600 Loss 0.1605
# Epoch 22 Batch 700 Loss 0.1879
# Epoch 22 Batch 800 Loss 0.2411
# Epoch 22 Batch 900 Loss 0.1773
# Epoch 22 Batch 1000 Loss 0.1010
# Epoch 22 Batch 1100 Loss 0.1869
# Epoch 22 Batch 1200 Loss 0.1733
# Epoch 22 Loss 0.1719
# Time taken for 1 epoch 246.9509584903717 sec
#
# Epoch 23 Batch 0 Loss 0.0992
# Epoch 23 Batch 100 Loss 0.1016
# Epoch 23 Batch 200 Loss 0.1429
# Epoch 23 Batch 300 Loss 0.0765
# Epoch 23 Batch 400 Loss 0.1959
# Epoch 23 Batch 500 Loss 0.1477
# Epoch 23 Batch 600 Loss 0.1486
# Epoch 23 Batch 700 Loss 0.1748
# Epoch 23 Batch 800 Loss 0.2008
# Epoch 23 Batch 900 Loss 0.1871
# Epoch 23 Batch 1000 Loss 0.1541
# Epoch 23 Batch 1100 Loss 0.1602
# Epoch 23 Batch 1200 Loss 0.2173
# Epoch 23 Loss 0.1765
# Time taken for 1 epoch 245.43775606155396 sec
#
# Epoch 24 Batch 0 Loss 0.1375
# Epoch 24 Batch 100 Loss 0.1090
# Epoch 24 Batch 200 Loss 0.1144
# Epoch 24 Batch 300 Loss 0.1414
# Epoch 24 Batch 400 Loss 0.1607
# Epoch 24 Batch 500 Loss 0.1905
# Epoch 24 Batch 600 Loss 0.2299
# Epoch 24 Batch 700 Loss 0.1413
# Epoch 24 Batch 800 Loss 0.1631
# Epoch 24 Batch 900 Loss 0.1651
# Epoch 24 Batch 1000 Loss 0.1910
# Epoch 24 Batch 1100 Loss 0.2195
# Epoch 24 Batch 1200 Loss 0.1611
# Epoch 24 Loss 0.1702
# Time taken for 1 epoch 246.64623498916626 sec
#
# Epoch 25 Batch 0 Loss 0.1549
# Epoch 25 Batch 100 Loss 0.1558
# Epoch 25 Batch 200 Loss 0.1334
# Epoch 25 Batch 300 Loss 0.1658
# Epoch 25 Batch 400 Loss 0.1752
# Epoch 25 Batch 500 Loss 0.1149
# Epoch 25 Batch 600 Loss 0.1885
# Epoch 25 Batch 700 Loss 0.1656
# Epoch 25 Batch 800 Loss 0.1901
# Epoch 25 Batch 900 Loss 0.1849
# Epoch 25 Batch 1000 Loss 0.2690
# Epoch 25 Batch 1100 Loss 0.2686
# Epoch 25 Batch 1200 Loss 0.1751
# Epoch 25 Loss 0.1755
# Time taken for 1 epoch 245.7066240310669 sec
#
# Epoch 26 Batch 0 Loss 0.1648
# Epoch 26 Batch 100 Loss 0.1581
# Epoch 26 Batch 200 Loss 0.1716
# Epoch 26 Batch 300 Loss 0.2219
# Epoch 26 Batch 400 Loss 0.1568
# Epoch 26 Batch 500 Loss 0.1837
# Epoch 26 Batch 600 Loss 0.1786
# Epoch 26 Batch 700 Loss 0.2014
# Epoch 26 Batch 800 Loss 0.1464
# Epoch 26 Batch 900 Loss 0.2379
# Epoch 26 Batch 1000 Loss 0.1866
# Epoch 26 Batch 1100 Loss 0.1594
# Epoch 26 Batch 1200 Loss 0.1508
# Epoch 26 Loss 0.1758
# Time taken for 1 epoch 246.87929511070251 sec
#
# Epoch 27 Batch 0 Loss 0.1920
# Epoch 27 Batch 100 Loss 0.1406
# Epoch 27 Batch 200 Loss 0.1551
# Epoch 27 Batch 300 Loss 0.2208
# Epoch 27 Batch 400 Loss 0.1289
# Epoch 27 Batch 500 Loss 0.2159
# Epoch 27 Batch 600 Loss 0.1936
# Epoch 27 Batch 700 Loss 0.1159
# Epoch 27 Batch 800 Loss 0.1493
# Epoch 27 Batch 900 Loss 0.1829
# Epoch 27 Batch 1000 Loss 0.2838
# Epoch 27 Batch 1100 Loss 0.2313
# Epoch 27 Batch 1200 Loss 0.2019
# Epoch 27 Loss 0.1739
# Time taken for 1 epoch 245.3938024044037 sec
#
# Epoch 28 Batch 0 Loss 0.1205
# Epoch 28 Batch 100 Loss 0.1560
# Epoch 28 Batch 200 Loss 0.1962
# Epoch 28 Batch 300 Loss 0.2069
# Epoch 28 Batch 400 Loss 0.1915
# Epoch 28 Batch 500 Loss 0.1789
# Epoch 28 Batch 600 Loss 0.1788
# Epoch 28 Batch 700 Loss 0.2404
# Epoch 28 Batch 800 Loss 0.1972
# Epoch 28 Batch 900 Loss 0.2125
# Epoch 28 Batch 1000 Loss 0.1965
# Epoch 28 Batch 1100 Loss 0.1884
# Epoch 28 Batch 1200 Loss 0.2373
# Epoch 28 Loss 0.1790
# Time taken for 1 epoch 246.36897659301758 sec
#
# Epoch 29 Batch 0 Loss 0.0880
# Epoch 29 Batch 100 Loss 0.1937
# Epoch 29 Batch 200 Loss 0.1234
# Epoch 29 Batch 300 Loss 0.1207
# Epoch 29 Batch 400 Loss 0.1301
# Epoch 29 Batch 500 Loss 0.2467
# Epoch 29 Batch 600 Loss 0.1224
# Epoch 29 Batch 700 Loss 0.2537
# Epoch 29 Batch 800 Loss 0.2230
# Epoch 29 Batch 900 Loss 0.2070
# Epoch 29 Batch 1000 Loss 0.1888
# Epoch 29 Batch 1100 Loss 0.2197
# Epoch 29 Batch 1200 Loss 0.2071
# Epoch 29 Loss 0.1802
# Time taken for 1 epoch 245.46098685264587 sec
#
# Epoch 30 Batch 0 Loss 0.0827
# Epoch 30 Batch 100 Loss 0.1803
# Epoch 30 Batch 200 Loss 0.0971
# Epoch 30 Batch 300 Loss 0.1923
# Epoch 30 Batch 400 Loss 0.2421
# Epoch 30 Batch 500 Loss 0.1533
# Epoch 30 Batch 600 Loss 0.1640
# Epoch 30 Batch 700 Loss 0.2016
# Epoch 30 Batch 800 Loss 0.2274
# Epoch 30 Batch 900 Loss 0.2085
# Epoch 30 Batch 1000 Loss 0.1701
# Epoch 30 Batch 1100 Loss 0.1766
# Epoch 30 Batch 1200 Loss 0.2395
# Epoch 30 Loss 0.1847
# Time taken for 1 epoch 245.8072919845581 sec
#
# Epoch 31 Batch 0 Loss 0.1743
# Epoch 31 Batch 100 Loss 0.1620
# Epoch 31 Batch 200 Loss 0.1434
# Epoch 31 Batch 300 Loss 0.2113
# Epoch 31 Batch 400 Loss 0.2068
# Epoch 31 Batch 500 Loss 0.2185
# Epoch 31 Batch 600 Loss 0.1195
# Epoch 31 Batch 700 Loss 0.1880
# Epoch 31 Batch 800 Loss 0.2125
# Epoch 31 Batch 900 Loss 0.1949
# Epoch 31 Batch 1000 Loss 0.2306
# Epoch 31 Batch 1100 Loss 0.1598
# Epoch 31 Batch 1200 Loss 0.2220
# Epoch 31 Loss 0.1847
# Time taken for 1 epoch 244.71036195755005 sec
#
# Epoch 32 Batch 0 Loss 0.1644
# Epoch 32 Batch 100 Loss 0.1523
# Epoch 32 Batch 200 Loss 0.1046
# Epoch 32 Batch 300 Loss 0.1973
# Epoch 32 Batch 400 Loss 0.1997
# Epoch 32 Batch 500 Loss 0.1266
# Epoch 32 Batch 600 Loss 0.1676
# Epoch 32 Batch 700 Loss 0.2320
# Epoch 32 Batch 800 Loss 0.1103
# Epoch 32 Batch 900 Loss 0.2035
# Epoch 32 Batch 1000 Loss 0.2004
# Epoch 32 Batch 1100 Loss 0.1795
# Epoch 32 Batch 1200 Loss 0.1613
# Epoch 32 Loss 0.1849
# Time taken for 1 epoch 245.63001585006714 sec
#
# Epoch 33 Batch 0 Loss 0.1806
# Epoch 33 Batch 100 Loss 0.1690
# Epoch 33 Batch 200 Loss 0.1776
# Epoch 33 Batch 300 Loss 0.1483
# Epoch 33 Batch 400 Loss 0.1367
# Epoch 33 Batch 500 Loss 0.1080
# Epoch 33 Batch 600 Loss 0.1784
# Epoch 33 Batch 700 Loss 0.2082
# Epoch 33 Batch 800 Loss 0.1858
# Epoch 33 Batch 900 Loss 0.3274
# Epoch 33 Batch 1000 Loss 0.1899
# Epoch 33 Batch 1100 Loss 0.2031
# Epoch 33 Batch 1200 Loss 0.2315
# Epoch 33 Loss 0.1855
# Time taken for 1 epoch 244.8313183784485 sec
#
# Epoch 34 Batch 0 Loss 0.1475
# Epoch 34 Batch 100 Loss 0.1739
# Epoch 34 Batch 200 Loss 0.1720
# Epoch 34 Batch 300 Loss 0.1559
# Epoch 34 Batch 400 Loss 0.1528
# Epoch 34 Batch 500 Loss 0.1700
# Epoch 34 Batch 600 Loss 0.1812
# Epoch 34 Batch 700 Loss 0.1938
# Epoch 34 Batch 800 Loss 0.2591
# Epoch 34 Batch 900 Loss 0.1711
# Epoch 34 Batch 1000 Loss 0.1322
# Epoch 34 Batch 1100 Loss 0.2175
# Epoch 34 Batch 1200 Loss 0.2188
# Epoch 34 Loss 0.1916
# Time taken for 1 epoch 245.26830387115479 sec
#
# Epoch 35 Batch 0 Loss 0.1660
# Epoch 35 Batch 100 Loss 0.1667
# Epoch 35 Batch 200 Loss 0.2343
# Epoch 35 Batch 300 Loss 0.2002
# Epoch 35 Batch 400 Loss 0.2431
# Epoch 35 Batch 500 Loss 0.1888
# Epoch 35 Batch 600 Loss 0.2315
# Epoch 35 Batch 700 Loss 0.1691
# Epoch 35 Batch 800 Loss 0.2025
# Epoch 35 Batch 900 Loss 0.2311
# Epoch 35 Batch 1000 Loss 0.2291
# Epoch 35 Batch 1100 Loss 0.1949
# Epoch 35 Batch 1200 Loss 0.2298
# Epoch 35 Loss 0.1893
# Time taken for 1 epoch 244.1773645877838 sec
#
# Epoch 36 Batch 0 Loss 0.1322
# Epoch 36 Batch 100 Loss 0.1492
# Epoch 36 Batch 200 Loss 0.1776
# Epoch 36 Batch 300 Loss 0.1466
# Epoch 36 Batch 400 Loss 0.1921
# Epoch 36 Batch 500 Loss 0.1647
# Epoch 36 Batch 600 Loss 0.2448
# Epoch 36 Batch 700 Loss 0.2018
# Epoch 36 Batch 800 Loss 0.2450
# Epoch 36 Batch 900 Loss 0.2026
# Epoch 36 Batch 1000 Loss 0.2323
# Epoch 36 Batch 1100 Loss 0.2188
# Epoch 36 Batch 1200 Loss 0.2112
# Epoch 36 Loss 0.1925
# Time taken for 1 epoch 245.52346968650818 sec
#
# Epoch 37 Batch 0 Loss 0.2262
# Epoch 37 Batch 100 Loss 0.1452
# Epoch 37 Batch 200 Loss 0.2174
# Epoch 37 Batch 300 Loss 0.1677
# Epoch 37 Batch 400 Loss 0.1212
# Epoch 37 Batch 500 Loss 0.1835
# Epoch 37 Batch 600 Loss 0.2287
# Epoch 37 Batch 700 Loss 0.1876
# Epoch 37 Batch 800 Loss 0.2899
# Epoch 37 Batch 900 Loss 0.2349
# Epoch 37 Batch 1000 Loss 0.2128
# Epoch 37 Batch 1100 Loss 0.1969
# Epoch 37 Batch 1200 Loss 0.2737
# Epoch 37 Loss 0.1969
# Time taken for 1 epoch 244.3889856338501 sec
#
# Epoch 38 Batch 0 Loss 0.1596
# Epoch 38 Batch 100 Loss 0.1685
# Epoch 38 Batch 200 Loss 0.2276
# Epoch 38 Batch 300 Loss 0.1788
# Epoch 38 Batch 400 Loss 0.1645
# Epoch 38 Batch 500 Loss 0.2093
# Epoch 38 Batch 600 Loss 0.1777
# Epoch 38 Batch 700 Loss 0.1898
# Epoch 38 Batch 800 Loss 0.1710
# Epoch 38 Batch 900 Loss 0.2661
# Epoch 38 Batch 1000 Loss 0.2056
# Epoch 38 Batch 1100 Loss 0.2560
# Epoch 38 Batch 1200 Loss 0.1881
# Epoch 38 Loss 0.2002
# Time taken for 1 epoch 245.6709690093994 sec
#
# Epoch 39 Batch 0 Loss 0.1768
# Epoch 39 Batch 100 Loss 0.1933
# Epoch 39 Batch 200 Loss 0.2546
# Epoch 39 Batch 300 Loss 0.2006
# Epoch 39 Batch 400 Loss 0.2042
# Epoch 39 Batch 500 Loss 0.2439
# Epoch 39 Batch 600 Loss 0.2587
# Epoch 39 Batch 700 Loss 0.2274
# Epoch 39 Batch 800 Loss 0.1910
# Epoch 39 Batch 900 Loss 0.2068
# Epoch 39 Batch 1000 Loss 0.3127
# Epoch 39 Batch 1100 Loss 0.1936
# Epoch 39 Batch 1200 Loss 0.2653
# Epoch 39 Loss 0.1994
# Time taken for 1 epoch 244.87823939323425 sec
#
# Epoch 40 Batch 0 Loss 0.1420
# Epoch 40 Batch 100 Loss 0.1484
# Epoch 40 Batch 200 Loss 0.1612
# Epoch 40 Batch 300 Loss 0.1549
# Epoch 40 Batch 400 Loss 0.1871
# Epoch 40 Batch 500 Loss 0.2151
# Epoch 40 Batch 600 Loss 0.2167
# Epoch 40 Batch 700 Loss 0.2187
# Epoch 40 Batch 800 Loss 0.1823
# Epoch 40 Batch 900 Loss 0.2356
# Epoch 40 Batch 1000 Loss 0.2098
# Epoch 40 Batch 1100 Loss 0.1896
# Epoch 40 Batch 1200 Loss 0.2116
# Epoch 40 Loss 0.1959
# Time taken for 1 epoch 247.44033122062683 sec
#
# Epoch 41 Batch 0 Loss 0.1757
# Epoch 41 Batch 100 Loss 0.1956
# Epoch 41 Batch 200 Loss 0.2005
# Epoch 41 Batch 300 Loss 0.1537
# Epoch 41 Batch 400 Loss 0.1777
# Epoch 41 Batch 500 Loss 0.2200
# Epoch 41 Batch 600 Loss 0.1727
# Epoch 41 Batch 700 Loss 0.1627
# Epoch 41 Batch 800 Loss 0.1677
# Epoch 41 Batch 900 Loss 0.2487
# Epoch 41 Batch 1000 Loss 0.2365
# Epoch 41 Batch 1100 Loss 0.1953
# Epoch 41 Batch 1200 Loss 0.2454
# Epoch 41 Loss 0.2011
# Time taken for 1 epoch 248.20171737670898 sec
#
# Epoch 42 Batch 0 Loss 0.1361
# Epoch 42 Batch 100 Loss 0.2038
# Epoch 42 Batch 200 Loss 0.2022
# Epoch 42 Batch 300 Loss 0.1690
# Epoch 42 Batch 400 Loss 0.1972
# Epoch 42 Batch 500 Loss 0.2497
# Epoch 42 Batch 600 Loss 0.2766
# Epoch 42 Batch 700 Loss 0.1614
# Epoch 42 Batch 800 Loss 0.2554
# Epoch 42 Batch 900 Loss 0.1534
# Epoch 42 Batch 1000 Loss 0.2059
# Epoch 42 Batch 1100 Loss 0.2023
# Epoch 42 Batch 1200 Loss 0.1922
# Epoch 42 Loss 0.2116
# Time taken for 1 epoch 249.44670224189758 sec
#
# Epoch 43 Batch 0 Loss 0.1536
# Epoch 43 Batch 100 Loss 0.1843
# Epoch 43 Batch 200 Loss 0.1997
# Epoch 43 Batch 300 Loss 0.1678
# Epoch 43 Batch 400 Loss 0.2013
# Epoch 43 Batch 500 Loss 0.1703
# Epoch 43 Batch 600 Loss 0.1793
# Epoch 43 Batch 700 Loss 0.1658
# Epoch 43 Batch 800 Loss 0.1993
# Epoch 43 Batch 900 Loss 0.2323
# Epoch 43 Batch 1000 Loss 0.2647
# Epoch 43 Batch 1100 Loss 0.2305
# Epoch 43 Batch 1200 Loss 0.2516
# Epoch 43 Loss 0.2103
# Time taken for 1 epoch 247.98174381256104 sec
#
# Epoch 44 Batch 0 Loss 0.1594
# Epoch 44 Batch 100 Loss 0.1834
# Epoch 44 Batch 200 Loss 0.2449
# Epoch 44 Batch 300 Loss 0.1834
# Epoch 44 Batch 400 Loss 0.1790
# Epoch 44 Batch 500 Loss 0.2424
# Epoch 44 Batch 600 Loss 0.1753
# Epoch 44 Batch 700 Loss 0.2215
# Epoch 44 Batch 800 Loss 0.2194
# Epoch 44 Batch 900 Loss 0.2261
# Epoch 44 Batch 1000 Loss 0.2313
# Epoch 44 Batch 1100 Loss 0.2661
# Epoch 44 Batch 1200 Loss 0.1814
# Epoch 44 Loss 0.2111
# Time taken for 1 epoch 248.7024073600769 sec
#
# Epoch 45 Batch 0 Loss 0.2347
# Epoch 45 Batch 100 Loss 0.2056
# Epoch 45 Batch 200 Loss 0.1754
# Epoch 45 Batch 300 Loss 0.1401
# Epoch 45 Batch 400 Loss 0.1801
# Epoch 45 Batch 500 Loss 0.2535
# Epoch 45 Batch 600 Loss 0.2231
# Epoch 45 Batch 700 Loss 0.1587
# Epoch 45 Batch 800 Loss 0.1680
# Epoch 45 Batch 900 Loss 0.2399
# Epoch 45 Batch 1000 Loss 0.2922
# Epoch 45 Batch 1100 Loss 0.1855
# Epoch 45 Batch 1200 Loss 0.2855
# Epoch 45 Loss 0.2109
# Time taken for 1 epoch 247.43840265274048 sec
#
# Epoch 46 Batch 0 Loss 0.1534
# Epoch 46 Batch 100 Loss 0.1423
# Epoch 46 Batch 200 Loss 0.2626
# Epoch 46 Batch 300 Loss 0.1864
# Epoch 46 Batch 400 Loss 0.2344
# Epoch 46 Batch 500 Loss 0.2078
# Epoch 46 Batch 600 Loss 0.2094
# Epoch 46 Batch 700 Loss 0.1979
# Epoch 46 Batch 800 Loss 0.2567
# Epoch 46 Batch 900 Loss 0.2819
# Epoch 46 Batch 1000 Loss 0.3374
# Epoch 46 Batch 1100 Loss 0.2467
# Epoch 46 Batch 1200 Loss 0.2438
# Epoch 46 Loss 0.2199
# Time taken for 1 epoch 248.3897042274475 sec
#
# Epoch 47 Batch 0 Loss 0.2408
# Epoch 47 Batch 100 Loss 0.2151
# Epoch 47 Batch 200 Loss 0.1982
# Epoch 47 Batch 300 Loss 0.2716
# Epoch 47 Batch 400 Loss 0.2289
# Epoch 47 Batch 500 Loss 0.2503
# Epoch 47 Batch 600 Loss 0.2358
# Epoch 47 Batch 700 Loss 0.2369
# Epoch 47 Batch 800 Loss 0.2464
# Epoch 47 Batch 900 Loss 0.2719
# Epoch 47 Batch 1000 Loss 0.2058
# Epoch 47 Batch 1100 Loss 0.2936
# Epoch 47 Batch 1200 Loss 0.3680
# Epoch 47 Loss 0.2281
# Time taken for 1 epoch 247.1847779750824 sec
#
# Epoch 48 Batch 0 Loss 0.1578
# Epoch 48 Batch 100 Loss 0.1540
# Epoch 48 Batch 200 Loss 0.2321
# Epoch 48 Batch 300 Loss 0.2169
# Epoch 48 Batch 400 Loss 0.1502
# Epoch 48 Batch 500 Loss 0.1745
# Epoch 48 Batch 600 Loss 0.2219
# Epoch 48 Batch 700 Loss 0.2265
# Epoch 48 Batch 800 Loss 0.2381
# Epoch 48 Batch 900 Loss 0.3268
# Epoch 48 Batch 1000 Loss 0.2358
# Epoch 48 Batch 1100 Loss 0.2655
# Epoch 48 Batch 1200 Loss 0.2646
# Epoch 48 Loss 0.2213
# Time taken for 1 epoch 248.44537377357483 sec
#
# Epoch 49 Batch 0 Loss 0.1698
# Epoch 49 Batch 100 Loss 0.1593
# Epoch 49 Batch 200 Loss 0.1912
# Epoch 49 Batch 300 Loss 0.2273
# Epoch 49 Batch 400 Loss 0.1792
# Epoch 49 Batch 500 Loss 0.1993
# Epoch 49 Batch 600 Loss 0.1359
# Epoch 49 Batch 700 Loss 0.2310
# Epoch 49 Batch 800 Loss 0.2572
# Epoch 49 Batch 900 Loss 0.1854
# Epoch 49 Batch 1000 Loss 0.2318
# Epoch 49 Batch 1100 Loss 0.1669
# Epoch 49 Batch 1200 Loss 0.1967
# Epoch 49 Loss 0.2197
# Time taken for 1 epoch 246.5732536315918 sec
#
# Epoch 50 Batch 0 Loss 0.2395
# Epoch 50 Batch 100 Loss 0.1531
# Epoch 50 Batch 200 Loss 0.2054
# Epoch 50 Batch 300 Loss 0.1876
# Epoch 50 Batch 400 Loss 0.2271
# Epoch 50 Batch 500 Loss 0.2161
# Epoch 50 Batch 600 Loss 0.2728
# Epoch 50 Batch 700 Loss 0.2195
# Epoch 50 Batch 800 Loss 0.2266
# Epoch 50 Batch 900 Loss 0.1667
# Epoch 50 Batch 1000 Loss 0.1855
# Epoch 50 Batch 1100 Loss 0.2379
# Epoch 50 Batch 1200 Loss 0.3209
# Epoch 50 Loss 0.2221
# Time taken for 1 epoch 247.56447196006775 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's not a bus . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: are you still home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do that . <end>

# %%
translate(u'Я люблю, когда идет снег.')
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i like rain . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>
